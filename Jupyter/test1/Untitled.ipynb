# %%
import os
os.listdir()
# Out:
# ['Untitled.ipynb',
#  'supermarkets.json',
#  'testing.ipynb',
#  'supermarkets.csv',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.xlsx',
#  '.ipynb_checkpoints',
#  'supermarkets-commas.txt']

# %%
import pandas
df1=pandas.read_csv("supermarkets.csv")

# %%
print df1
# Out:
#   File "<ipython-input-3-5aaf2e48b39d>", line 1
#     print df1
#             ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(df1)?

# %%
print(df1)
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2=pandas.read_json("supermarkets.json")
print(df2)
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3=pandas.read_excel("supermarkets.xlsx",sheet_name=0)

# %%
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4=pandas.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5=pandas.read_csv("supermarkets-semi-colons.txt",sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
pandas?

# %%
pandas.read_csv?

# %%
df5.set_index("ID")
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5.columns
# Out:
# Index(['ID', 'Address', 'City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
df6=df5.set_index("ID")

# %%
df6
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5.set_index("ID",inplace=True)

# %%
df5
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5.loc[1,"City"]
# Out:
# 'San Francisco'

# %%
df5.loc[3,"Name"]
# Out:
# ' Super River'

# %%
df5.loc[3:5,"Name"]
# Out:
# ID
# 3     Super River
# 4      Ben's Shop
# 5         Sanchez
# Name: Name, dtype: object

# %%
mylist=list(df5.loc[3:5,"Name"])

# %%
mylist
# Out:
# [' Super River', "Ben's Shop", 'Sanchez']

# %%
mylist[0]
# Out:
# ' Super River'

# %%
df5.loc[1,"Address"]
# Out:
# '3666 21st St'

# %%
df5.loc[(df5["Employees"]<15)&(df5["Employees"]>8),"Address"]
# Out:
# ID
# 4       3995 23rd St
# 5    1056 Sanchez St
# Name: Address, dtype: object

# %%
df5.drop("City",1)
# Out:
#             Address             State Country          Name  Employees
# ID
# 1      3666 21st St          CA 94114     USA       Madeira          8
# 2    735 Dolores St          CA 94119     USA   Bready Shop         15
# 3       332 Hill St  California 94114     USA   Super River         25
# 4      3995 23rd St          CA 94114     USA    Ben's Shop         10
# 5   1056 Sanchez St        California     USA       Sanchez         12
# 6   551 Alvarado St          CA 94114     USA    Richvalley         20

# %%
df5.drop(df5.index[0:3],0)
# Out:
#             Address           City       State Country        Name  Employees
# ID
# 4      3995 23rd St  San Francisco    CA 94114     USA  Ben's Shop         10
# 5   1056 Sanchez St  San Francisco  California     USA     Sanchez         12
# 6   551 Alvarado St  San Francisco    CA 94114     USA  Richvalley         20

# %%
df5
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5.drop(df5.columns[0:2],1)
# Out:
#                State Country          Name  Employees
# ID
# 1           CA 94114     USA       Madeira          8
# 2           CA 94119     USA   Bready Shop         15
# 3   California 94114     USA   Super River         25
# 4           CA 94114     USA    Ben's Shop         10
# 5         California     USA       Sanchez         12
# 6           CA 94114     USA    Richvalley         20

# %%
df5["Continent"]=df5.shape[0]*["North America"]

# %%
df5
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees      Continent
# ID
# 1           8  North America
# 2          15  North America
# 3          25  North America
# 4          10  North America
# 5          12  North America
# 6          20  North America

# %%
df5_t=df5.T

# %%
df5_t
# Out:
# ID                     1               2                 3              4  \
# Address     3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City       San Francisco   San Francisco     San Francisco  San Francisco
# State           CA 94114        CA 94119  California 94114       CA 94114
# Country              USA             USA               USA            USA
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# Employees              8              15                25             10
# Continent  North America   North America     North America  North America
#
# ID                       5                6
# Address    1056 Sanchez St  551 Alvarado St
# City         San Francisco    San Francisco
# State           California         CA 94114
# Country                USA              USA
# Name               Sanchez       Richvalley
# Employees               12               20
# Continent    North America    North America

# %%
df5_t[7]=["My Address","My City","My State","My Country","My Name","10","North America"]

# %%
df5_t
# Out:
# ID                     1               2                 3              4  \
# Address     3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City       San Francisco   San Francisco     San Francisco  San Francisco
# State           CA 94114        CA 94119  California 94114       CA 94114
# Country              USA             USA               USA            USA
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# Employees              8              15                25             10
# Continent  North America   North America     North America  North America
#
# ID                       5                6              7
# Address    1056 Sanchez St  551 Alvarado St     My Address
# City         San Francisco    San Francisco        My City
# State           California         CA 94114       My State
# Country                USA              USA     My Country
# Name               Sanchez       Richvalley        My Name
# ...

# %%
df5=df5_t.T

# %%
df5
# Out:
#             Address           City             State     Country  \
# ID
# 1      3666 21st St  San Francisco          CA 94114         USA
# 2    735 Dolores St  San Francisco          CA 94119         USA
# 3       332 Hill St  San Francisco  California 94114         USA
# 4      3995 23rd St  San Francisco          CA 94114         USA
# 5   1056 Sanchez St  San Francisco        California         USA
# 6   551 Alvarado St  San Francisco          CA 94114         USA
# 7        My Address        My City          My State  My Country
#
#             Name Employees      Continent
# ID
# 1        Madeira         8  North America
# 2    Bready Shop        15  North America
# 3    Super River        25  North America
# 4     Ben's Shop        10  North America
# 5        Sanchez        12  North America
# 6     Richvalley        20  North America
# 7        My Name        10  North America

# %%
df5["Continent"]=df5["Country"]+","+"North America"

# %%
df5
# Out:
#             Address           City             State     Country  \
# ID
# 1      3666 21st St  San Francisco          CA 94114         USA
# 2    735 Dolores St  San Francisco          CA 94119         USA
# 3       332 Hill St  San Francisco  California 94114         USA
# 4      3995 23rd St  San Francisco          CA 94114         USA
# 5   1056 Sanchez St  San Francisco        California         USA
# 6   551 Alvarado St  San Francisco          CA 94114         USA
# 7        My Address        My City          My State  My Country
#
#             Name Employees                 Continent
# ID
# 1        Madeira         8         USA,North America
# 2    Bready Shop        15         USA,North America
# 3    Super River        25         USA,North America
# 4     Ben's Shop        10         USA,North America
# 5        Sanchez        12         USA,North America
# 6     Richvalley        20         USA,North America
# 7        My Name        10  My Country,North America

# %%
df5.iloc[6,3]
# Out:
# 'My Country'

# %%
df5.iloc[6,3]="USA"

# %%
df5
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
# 7        My Address        My City          My State     USA       My Name
#
#    Employees                 Continent
# ID
# 1          8         USA,North America
# 2         15         USA,North America
# 3         25         USA,North America
# 4         10         USA,North America
# 5         12         USA,North America
# 6         20         USA,North America
# 7         10  My Country,North America

# %%
df5.shape
# Out:
# (7, 7)

# %%
import geopy

# %%
geopy?

# %%
list dir(geopy)
# Out:
#   File "<ipython-input-71-38b317e3e4f5>", line 1
#     list dir(geopy)
#            ^
# SyntaxError: invalid syntax

# %%
dir(geopy)
# Out:
# ['ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
dir(geopy.geocoders)
# Out:
# ['ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'GeocoderNotFound',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'MapBox',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'SERVICE_TO_GEOCODER',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'arcgis',
#  'azure',
#  'baidu',
#  'banfrance',
#  'base',
#  'bing',
#  'databc',
#  'geocodeearth',
#  'geocodefarm',
#  'geolake',
#  'geonames',
#  'get_geocoder_for_service',
#  'googlev3',
#  'here',
#  'ignfrance',
#  'mapbox',
#  'opencage',
#  'openmapquest',
#  'options',
#  'osm',
#  'pelias',
#  'photon',
#  'pickpoint',
#  'smartystreets',
#  'tomtom',
#  'what3words',
#  'yandex']

# %%
from geopy.geocoders import ArcGIS

# %%
nom=ArcGIS()

# %%
n = nom.geocode("6620 W149th St, Overland  Park,Kansas 66223")

# %%
 nom.geocode("6620 W149th St, Overland  Park,Kansas 66223")
# Out:
# Location(66223, Overland Park, Kansas, (38.862288800000044, -94.66602999999998, 0.0))

# %%
df5
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
# 7        My Address        My City          My State     USA       My Name
#
#    Employees                 Continent
# ID
# 1          8         USA,North America
# 2         15         USA,North America
# 3         25         USA,North America
# 4         10         USA,North America
# 5         12         USA,North America
# 6         20         USA,North America
# 7         10  My Country,North America

# %%
df5["Address"]=df5["Address"]+", "+df5["City"]+", "+df5["State"]
df5
# Out:
#                                          Address           City  \
# ID
# 1          3666 21st St, San Francisco, CA 94114  San Francisco
# 2        735 Dolores St, San Francisco, CA 94119  San Francisco
# 3   332 Hill St, San Francisco, California 94114  San Francisco
# 4          3995 23rd St, San Francisco, CA 94114  San Francisco
# 5     1056 Sanchez St, San Francisco, California  San Francisco
# 6       551 Alvarado St, San Francisco, CA 94114  San Francisco
# 7                  My Address, My City, My State        My City
#
#                State Country          Name Employees                 Continent
# ID
# 1           CA 94114     USA       Madeira         8         USA,North America
# 2           CA 94119     USA   Bready Shop        15         USA,North America
# 3   California 94114     USA   Super River        25         USA,North America
# 4           CA 94114     USA    Ben's Shop        10         USA,North America
# ...

# %%
df5["Coordinates"]=df5["Address"].apply(nom.geocode)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# /opt/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# /opt/anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# /opt/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
# ...

# %%
df5.drop(7,0)
# Out:
#                                          Address           City  \
# ID
# 1          3666 21st St, San Francisco, CA 94114  San Francisco
# 2        735 Dolores St, San Francisco, CA 94119  San Francisco
# 3   332 Hill St, San Francisco, California 94114  San Francisco
# 4          3995 23rd St, San Francisco, CA 94114  San Francisco
# 5     1056 Sanchez St, San Francisco, California  San Francisco
# 6       551 Alvarado St, San Francisco, CA 94114  San Francisco
#
#                State Country          Name Employees          Continent  \
# ID
# 1           CA 94114     USA       Madeira         8  USA,North America
# 2           CA 94119     USA   Bready Shop        15  USA,North America
# 3   California 94114     USA   Super River        25  USA,North America
# 4           CA 94114     USA    Ben's Shop        10  USA,North America
# 5         California     USA       Sanchez        12  USA,North America
# 6           CA 94114     USA    Richvalley        20  USA,North America
#
# ...

# %%
df5["Coordinates"]=df5["Address"].apply(nom.geocode)

# %%
df5
# Out:
#                                          Address           City  \
# ID
# 1          3666 21st St, San Francisco, CA 94114  San Francisco
# 2        735 Dolores St, San Francisco, CA 94119  San Francisco
# 3   332 Hill St, San Francisco, California 94114  San Francisco
# 4          3995 23rd St, San Francisco, CA 94114  San Francisco
# 5     1056 Sanchez St, San Francisco, California  San Francisco
# 6       551 Alvarado St, San Francisco, CA 94114  San Francisco
# 7                  My Address, My City, My State        My City
#
#                State Country          Name Employees  \
# ID
# 1           CA 94114     USA       Madeira         8
# 2           CA 94119     USA   Bready Shop        15
# 3   California 94114     USA   Super River        25
# 4           CA 94114     USA    Ben's Shop        10
# 5         California     USA       Sanchez        12
# 6           CA 94114     USA    Richvalley        20
# 7           My State     USA       My Name        10
#
# ...

# %%
df5["Latitude"]=df5["Coordinates"].apply(lambda x:x.latitude if x!=None else None)

# %%
df5["Longitude"]=df5["Coordinates"].apply(lambda x:x.longitude if x!=None else None)

# %%
df5
# Out:
#                                          Address           City  \
# ID
# 1          3666 21st St, San Francisco, CA 94114  San Francisco
# 2        735 Dolores St, San Francisco, CA 94119  San Francisco
# 3   332 Hill St, San Francisco, California 94114  San Francisco
# 4          3995 23rd St, San Francisco, CA 94114  San Francisco
# 5     1056 Sanchez St, San Francisco, California  San Francisco
# 6       551 Alvarado St, San Francisco, CA 94114  San Francisco
# 7                  My Address, My City, My State        My City
#
#                State Country          Name Employees  \
# ID
# 1           CA 94114     USA       Madeira         8
# 2           CA 94119     USA   Bready Shop        15
# 3   California 94114     USA   Super River        25
# 4           CA 94114     USA    Ben's Shop        10
# 5         California     USA       Sanchez        12
# 6           CA 94114     USA    Richvalley        20
# 7           My State     USA       My Name        10
#
# ...

# %%
df5["Coordinates"][7]
# Out:
# Location(Alajuela, Orotina, Mastate, (9.910800000000052, -84.54534999999998, 0.0))
